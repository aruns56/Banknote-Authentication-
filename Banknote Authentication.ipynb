# %%
import pandas as pd
import numpy as np
import os
os.chdir("C://users//arun//Downloads")

# %%
df=pd.read_csv('BankNote_Authentication.csv')

# %%
df
# Out:
#       variance  skewness  curtosis  entropy  class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    variance  skewness  curtosis  entropy
# 0   3.62160    8.6661   -2.8073 -0.44699
# 1   4.54590    8.1674   -2.4586 -1.46210
# 2   3.86600   -2.6383    1.9242  0.10645
# 3   3.45660    9.5228   -4.0112 -3.59440
# 4   0.32924   -4.4552    4.5718 -0.98880

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1367    1
# 1368    1
# 1369    1
# 1370    1
# 1371    1
# Name: class, Length: 1372, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from pycaret.classification import *

# %%
reg=setup(data=df,target='class')
# Out:
# <style  type="text/css" >
# </style><table id="T_f9b47_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f9b47_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f9b47_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f9b47_row0_col1" class="data row0 col1" >4962</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f9b47_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_f9b47_row1_col1" class="data row1 col1" >class</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f9b47_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_f9b47_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f9b47_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_f9b47_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f9b47_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_f9b47_row4_col1" class="data row4 col1" >(1372, 5)</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f9b47_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_f9b47_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f9b47_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_f9b47_row6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f9b47_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_f9b47_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f9b47_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_f9b47_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f9b47_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_f9b47_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f9b47_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_f9b47_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f9b47_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_f9b47_row11_col1" class="data row11 col1" >(960, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f9b47_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_f9b47_row12_col1" class="data row12 col1" >(412, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f9b47_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_f9b47_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f9b47_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_f9b47_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f9b47_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_f9b47_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f9b47_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_f9b47_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f9b47_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_f9b47_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_f9b47_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_f9b47_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_f9b47_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_f9b47_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_f9b47_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_f9b47_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_f9b47_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_f9b47_row21_col1" class="data row21 col1" >c5d2</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_f9b47_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_f9b47_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_f9b47_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_f9b47_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f9b47_level0_row24" class="row_heading level0 row24" >24</th>
#                         <td id="T_f9b47_row24_col0" class="data row24 col

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_1118c_ th {
#           text-align: left;
#     }#T_1118c_row0_col0,#T_1118c_row1_col0,#T_1118c_row1_col1,#T_1118c_row1_col3,#T_1118c_row1_col4,#T_1118c_row1_col5,#T_1118c_row1_col6,#T_1118c_row1_col7,#T_1118c_row2_col0,#T_1118c_row2_col1,#T_1118c_row2_col2,#T_1118c_row2_col3,#T_1118c_row2_col4,#T_1118c_row2_col5,#T_1118c_row2_col6,#T_1118c_row2_col7,#T_1118c_row3_col0,#T_1118c_row3_col1,#T_1118c_row3_col2,#T_1118c_row3_col3,#T_1118c_row3_col4,#T_1118c_row3_col5,#T_1118c_row3_col6,#T_1118c_row3_col7,#T_1118c_row4_col0,#T_1118c_row4_col1,#T_1118c_row4_col2,#T_1118c_row4_col3,#T_1118c_row4_col4,#T_1118c_row4_col5,#T_1118c_row4_col6,#T_1118c_row4_col7,#T_1118c_row5_col0,#T_1118c_row5_col1,#T_1118c_row5_col2,#T_1118c_row5_col3,#T_1118c_row5_col4,#T_1118c_row5_col5,#T_1118c_row5_col6,#T_1118c_row5_col7,#T_1118c_row6_col0,#T_1118c_row6_col1,#T_1118c_row6_col2,#T_1118c_row6_col3,#T_1118c_row6_col4,#T_1118c_row6_col5,#T_1118c_row6_col6,#T_1118c_row6_col7,#T_1118c_row7_col0,#T_1118c_row7_col1,#T_1118c_row7_col2,#T_1118c_row7_col3,#T_1118c_row7_col4,#T_1118c_row7_col5,#T_1118c_row7_col6,#T_1118c_row7_col7,#T_1118c_row8_col0,#T_1118c_row8_col1,#T_1118c_row8_col2,#T_1118c_row8_col3,#T_1118c_row8_col4,#T_1118c_row8_col5,#T_1118c_row8_col6,#T_1118c_row8_col7,#T_1118c_row9_col0,#T_1118c_row9_col1,#T_1118c_row9_col4,#T_1118c_row9_col5,#T_1118c_row9_col6,#T_1118c_row9_col7,#T_1118c_row10_col0,#T_1118c_row10_col1,#T_1118c_row10_col2,#T_1118c_row10_col3,#T_1118c_row10_col4,#T_1118c_row10_col5,#T_1118c_row10_col6,#T_1118c_row10_col7,#T_1118c_row11_col0,#T_1118c_row11_col1,#T_1118c_row11_col2,#T_1118c_row11_col4,#T_1118c_row11_col5,#T_1118c_row11_col6,#T_1118c_row11_col7,#T_1118c_row12_col0,#T_1118c_row12_col1,#T_1118c_row12_col2,#T_1118c_row12_col4,#T_1118c_row12_col5,#T_1118c_row12_col6,#T_1118c_row12_col7,#T_1118c_row13_col0,#T_1118c_row13_col1,#T_1118c_row13_col2,#T_1118c_row13_col3,#T_1118c_row13_col4,#T_1118c_row13_col5,#T_1118c_row13_col6,#T_1118c_row13_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_1118c_row0_col1,#T_1118c_row0_col2,#T_1118c_row0_col3,#T_1118c_row0_col4,#T_1118c_row0_col5,#T_1118c_row0_col6,#T_1118c_row0_col7,#T_1118c_row1_col2,#T_1118c_row9_col2,#T_1118c_row9_col3,#T_1118c_row11_col3,#T_1118c_row12_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_1118c_row0_col8,#T_1118c_row1_col8,#T_1118c_row2_col8,#T_1118c_row3_col8,#T_1118c_row4_col8,#T_1118c_row5_col8,#T_1118c_row6_col8,#T_1118c_row7_col8,#T_1118c_row8_col8,#T_1118c_row9_col8,#T_1118c_row10_col8,#T_1118c_row12_col8,#T_1118c_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_1118c_row11_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_1118c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1118c_level0_row0" class="row_heading level0 row0" >knn</th>
#                         <td id="T_1118c_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#                         <td id="T_1118c_row0_col1" class="data row0 col1" >1.0000</td>
#                         <td id="T_1118c_row0_col2" class="data row0 col2" >1.0000</td>
#                         <td id="T_1118c_row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_1118c_row0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_1118c_row0_col5" class="data row0 col5" >1.0000</td>
#                         <td id="T_1118c_row0_col6" class="data row0 col6" >1.0000</td>
#                         <td id="T_1118c_row0_col7" class="data row0 col7" >1.0000</td>
#                         <td id="T_1118c_row0_col8" class="data row0 col8" >0.0150</td>
#             </tr>
#             <tr>
#                         <th id="T_1118c_level0_row1" class="row_heading level0 row1" >et</th>
#                         <td id="T_1118c_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#                         <td id="T_1118c_row1_col1" class="data row1 col1" >0.9979</td>
#                         <td id="T_1118c_row1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_1118c_row1_col3" class="data row1 col3" >0.9977</td>
#                         <td id="T_1118c_row1_col4" class="data row1 col4" >0.9977</td>
#                         <td id="T_1118c_row1_col5" class="data row1 col5" >0.9977</td>
#                         <td id="T_1118c_row1_col6" class="data row1 col6" >0.9958</td>
#                         <td id="T_1118c_row1_col7" class="data row1 col7" >0.9958</td>
#                         <td id="T_1118c_row1_col8" class="data row1 col8" >0.0680</td>
#             </tr>
#             <tr>
#                         <th id="T_1118c_level0_row2" class="row_heading level0 row2" >ada</th>
#                         <td id="T_1118c_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#                         <td id="T_1118c_row2_col1" class="data row2 col1" >0.9958</td>
#                         <td id="T_1118c_row2_col2" class="data row2 col2" >0.9996</td>
#                         <td id="T_1118c_row2_col3" class="data row2 col3" >0.9953</td>
#                         <td id="T_1118c_row2_col4" class="data row2 col4" >0.9956</td>
#                         <td id="T_1118c_row2_col5" class="data row2 col5" >0.9954</td>
#                         <td id="T_1118c_row2_col6" class="data row2 col6" >0.9916</td>
#                         <td id="T_1118c_row2_col7" class="data row2 col7" >0.9917</td>
#                         <td id="T_1118c_row2_col8" class="data row2 col8" >0.0360</td>
#             </tr>
#             <tr>
#                         <th id="T_1118c_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#                         <td id="T_1118c_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_1118c_row3_col1" class="data row3 col1" >0.9938</td>
#                         <td id="T_1118c_row3_col2" class="data row3 col2" >0.9993</td>
#                         <td id="T_1118c_row3_col3" class="data row3 col3" >0.9930</td>
#                         <td id="T_1118c_row3_col4" class="data row3 col4" >0.9933</td>
#                         <td id="T_1118c_row3_col5" class="data row3 col5" >0.9930</td>
#                         <td id="T_1118c_row3_col6" class="data row3 col6" >0.9874</td>
#                         <td id="T_1118c_row3_col7" class="data row3 col7" >0.9875</td>
#                         <td id="T_1118c_row3_col8" class="data row3 col8" >0.0820</td>
#             </tr>
#             <tr>
#                         <th id="T_1118c_level0_row4" class="row_heading level0 row4" >gbc</th>
#                         <td id="T_1118c_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_1118c_row4_col1" class="data row4 col1" >0.9917</td>
#                         <td id="T_1118c_row4_col2" class="data row4 col2" >0.9996</td>
#                         <td id="T_1118c_row4_col3" class="data row4 col3" >0.9907</td>
#                         <td id="T_1118c_row4_col4" class="data row4 col4" >0.9910</td>
#                         <td id="T_1118c_row4_col5" class="data row4 col5" >0.9907</td>
#                         <td id="T_1118c_row4_col6"
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                     metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
                     weights='uniform')
classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 1.0

# %%
import pickle
pickle_out = open("classifier.pkl","wb")
pickle.dump(classifier, pickle_out)
pickle_out.close()

# %%
classifier.predict([[1.1164,3.8095,-4.9408,-4.0909]])
# Out:
# array([1], dtype=int64)
